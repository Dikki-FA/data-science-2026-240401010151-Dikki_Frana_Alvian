# %% [markdown]
# # Hands-on Sesi 1 (modul)
#
# Dikki Frana Alvian
#
# 240401010151

# %% [markdown]
# # 1. Output sederhana

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# # 2. Variabel dan tipe data dasar

# %%
nama = "Dikki Frana Alvian" # String
angkatan = 2024 # Integer
ipk = 4.00 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Dikki Frana Alvian
# Angkatan : 2024
# IPK : 4.0
# Aktif : True

# %% [markdown]
# # 3. List dan perulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. Github

# %% [markdown]
# # 4. Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Dikki Frana Alvian", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Dikki Frana Alvian dari Informatika, angkatan 2024.
