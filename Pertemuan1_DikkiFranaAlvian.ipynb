# %% [markdown]
# # Hands-on Sesi 1
#
# Dikki Frana Alvian
#
# 240401010151

# %% [markdown]
# # 1. Output Sederhana

# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %% [markdown]
# # 2. Variabel & Tipe Data

# %%
nama = "Dikki Frana Alvian"
angkatan = 2024
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Dikki Frana Alvian angkatan 2024!

# %% [markdown]
# # 3. List & Perulangan

# %%
tools = ["Python", "Colab", "Jupyter", "Github"]
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. Github

# %% [markdown]
# # 4. Fungsi Python

# %%
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Dikki Frana Alvian", "Informatika", 2024))
# Out:
# Dikki Frana Alvian | Informatika | 2024
